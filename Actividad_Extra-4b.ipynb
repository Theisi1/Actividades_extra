# %% [markdown]
# ##  Actividad Extra

# %% [markdown]
# 1. Black Format

# %%
def suma(a,b):  return a+b
def resta(a , b):
 return a-b
def operacion(a,b,op):
 if op=="+":
  return suma(a,b)
 else:
  return resta(a,b)
