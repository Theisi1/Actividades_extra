# %% [markdown]
# #  Actividad Extra 4b
# ## Isaac Gonzalez
# ### Métodos Númericos

# %% [markdown]
# 1. Black Format

# %%
def suma(a,b):  return a+b
def resta(a , b):
 return a-b
def operacion(a,b,op):
 if op=="+":
  return suma(a,b)
 else:
  return resta(a,b)

# %% [markdown]
# Black
# Black es un formatter “opinionado”: no permite configuraciones extensas, aplica un solo estilo estándar.
#
# pip install black
# black archivo.py

# %%
def suma(a, b):
    return a + b


def resta(a, b):
    return a - b


def operacion(a, b, op):
    if op == "+":
        return suma(a, b)
    else:
        return resta(a, b)

# %% [markdown]
# autopep8
# Corrige el código siguiendo la norma PEP8
#
# pip install autopep8
# autopep8 --in-place archivo.py

# %%
def suma(a, b):
    return a + b


def resta(a, b):
    return a - b


def operacion(a, b, op):
    if op == "+":
        return suma(a, b)
    else:
        return resta(a, b)

# %% [markdown]
# YAPF
# YAPF (Yet Another Python Formatter) fue creado por Google y permite configuración personalizada.
#
# pip install yapf
# yapf -i archivo.py

# %%
def suma(a, b):
    return a + b


def resta(a, b):
    return a - b


def operacion(a, b, op):
    if op == "+":
        return suma(a, b)
    else:
        return resta(a, b)

# %% [markdown]
# Ruff
# Ruff es una herramienta moderna, muy rápida, que combina linter y formatter.
#
# pip install ruff
# ruff format archivo.py

# %%
def suma(a, b):
    return a + b


def resta(a, b):
    return a - b


def operacion(a, b, op):
    if op == "+":
        return suma(a, b)
    else:
        return resta(a, b)
